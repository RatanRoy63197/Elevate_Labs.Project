# %%
import pandas as pd

df=pd.read_csv(r"C:\Users\Xervice5433\Downloads\hospital_appointment_no_show_5000.csv")

print(df.head())
print(df.info())
# Out:
#    patient_id   age  gender city_type  distance_km  travel_time_min  \
# 0           1  47.0  Female  Suburban         16.5             77.3
# 1           2  37.0    Male  Suburban          6.7             26.9
# 2           3  49.0  Female     Rural          8.2             46.1
# 3           4  62.0  Female     Urban          2.6             15.2
# 4           5  36.0  Female  Suburban          4.1             13.8
#
#   appointment_day appointment_time_slot        department  waiting_days  ...  \
# 0             Sat               Evening        Pediatrics             8  ...
# 1             Tue               Morning        Cardiology             8  ...
# 2             Sat               Evening  General Medicine             3  ...
# 3             Thu               Evening  General Medicine            12  ...
# 4             Fri               Morning       Dermatology             8  ...
#
#    chronic_disease  sms_reminder  email_reminder  num_reminders  \
# ...

# %%
print(df.isnull().sum())
# Out:
# patient_id                 0
# age                      390
# gender                     0
# city_type                  0
# distance_km              388
# travel_time_min          416
# appointment_day            0
# appointment_time_slot      0
# department                 0
# waiting_days               0
# previous_appointments      0
# previous_no_shows          0
# diabetes                   0
# hypertension               0
# chronic_disease            0
# sms_reminder               0
# email_reminder           440
# num_reminders              0
# employment_status        388
# education_level          391
# insurance_status           0
# rainy_day                  0
# public_holiday             0
# no_show                    0
# dtype: int64

# %%
critical_cols = [
    'age',
    'distance_km',
    'travel_time_min',
    'employment_status',
    'education_level',
    'email_reminder'
]

df_clean = df.dropna(subset=critical_cols)

# %%
df_clean = df.dropna()

print("Before:", df.shape)
print("After:", df_clean.shape)
# Out:
# Before: (5000, 24)
# After: (3031, 24)

# %%
print(df.head())
# Out:
#    patient_id   age  gender city_type  distance_km  travel_time_min  \
# 0           1  47.0  Female  Suburban         16.5             77.3
# 1           2  37.0    Male  Suburban          6.7             26.9
# 2           3  49.0  Female     Rural          8.2             46.1
# 3           4  62.0  Female     Urban          2.6             15.2
# 4           5  36.0  Female  Suburban          4.1             13.8
#
#   appointment_day appointment_time_slot        department  waiting_days  ...  \
# 0             Sat               Evening        Pediatrics             8  ...
# 1             Tue               Morning        Cardiology             8  ...
# 2             Sat               Evening  General Medicine             3  ...
# 3             Thu               Evening  General Medicine            12  ...
# 4             Fri               Morning       Dermatology             8  ...
#
#    chronic_disease  sms_reminder  email_reminder  num_reminders  \
# ...

# %%
print(df.isnull().sum())
# Out:
# patient_id                 0
# age                        0
# gender                     0
# city_type                  0
# distance_km                0
# travel_time_min            0
# appointment_day            0
# appointment_time_slot      0
# department                 0
# waiting_days               0
# previous_appointments      0
# previous_no_shows          0
# diabetes                   0
# hypertension               0
# chronic_disease            0
# sms_reminder               0
# email_reminder           440
# num_reminders              0
# employment_status        388
# education_level          391
# insurance_status           0
# rainy_day                  0
# public_holiday             0
# no_show                    0
# dtype: int64

# %%
df['email_reminder'] = df['email_reminder'].fillna(0)

# %%
df['employment_status'] = df['employment_status'].fillna(
    df['employment_status'].mode()[0]
)

df['education_level'] = df['education_level'].fillna(
    df['education_level'].mode()[0]
)

# %%
print(df.isnull().sum())
# Out:
# patient_id               0
# age                      0
# gender                   0
# city_type                0
# distance_km              0
# travel_time_min          0
# appointment_day          0
# appointment_time_slot    0
# department               0
# waiting_days             0
# previous_appointments    0
# previous_no_shows        0
# diabetes                 0
# hypertension             0
# chronic_disease          0
# sms_reminder             0
# email_reminder           0
# num_reminders            0
# employment_status        0
# education_level          0
# insurance_status         0
# rainy_day                0
# public_holiday           0
# no_show                  0
# dtype: int64

# %%
print(df .drop_duplicates())
# Out:
#       patient_id   age  gender city_type  distance_km  travel_time_min  \
# 0              1  47.0  Female  Suburban         16.5             77.3
# 1              2  37.0    Male  Suburban          6.7             26.9
# 2              3  49.0  Female     Rural          8.2             46.1
# 3              4  62.0  Female     Urban          2.6             15.2
# 4              5  36.0  Female  Suburban          4.1             13.8
# ...          ...   ...     ...       ...          ...              ...
# 4995        4996  39.0  Female     Urban          7.9             35.3
# 4996        4997  50.0    Male  Suburban          5.1             24.2
# 4997        4998  86.0    Male     Rural          4.8             26.0
# 4998        4999  52.0    Male     Urban          8.1             41.0
# 4999        5000  27.0  Female  Suburban          5.2             40.7
#
#      appointment_day appointment_time_slot        department  waiting_days  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   patient_id             5000 non-null   int64
#  1   age                    5000 non-null   float64
#  2   gender                 5000 non-null   object
#  3   city_type              5000 non-null   object
#  4   distance_km            5000 non-null   float64
#  5   travel_time_min        5000 non-null   float64
#  6   appointment_day        5000 non-null   object
#  7   appointment_time_slot  5000 non-null   object
#  8   department             5000 non-null   object
#  9   waiting_days           5000 non-null   int64
#  10  previous_appointments  5000 non-null   int64
#  11  previous_no_shows      5000 non-null   int64
#  12  diabetes               5000 non-null   int64
#  13  hypertension           5000 non-null   int64
# ...
